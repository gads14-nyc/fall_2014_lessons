# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm

# %%
np.random.seed(0)
samples = 500
X = np.random.random(size=(samples, 1)) # The size of the input array is expected to be [n_samples, n_features]
y = 2 + 3 * X.squeeze() + np.random.normal(size=samples)
model = LinearRegression(fit_intercept=True)
model.fit(X, y)
print ("Model coefficient: %.5f, and intercept: %.5f"
       % (model.coef_, model.intercept_))
# Visualize this training dataset
X_test = np.linspace(0, 1, 100).reshape(100,1)
y_hat = model.predict(X_test)
plt.plot(X,y,'o')
plt.plot(X_test, y_hat, 'o')
# Out:
# Model coefficient: 3.02895, and intercept: 1.88551

# %%
# now let's try the same with statsmodels
ols = sm.OLS(y, X).fit()
ols.summary()

# %%
# The statsmodels library provides a small subset of models, but has more emphasis on
# parameter estimation and statistical testing. The summary output is similar to R's
# summary function.
# X is an "array" of column values, y is a single column value
#X = boston_df[["lstat"]].values
#X = sm.add_constant(X)  # add the intercept term #Our model needs an intercept so we add a column of 1s:
#y = boston_df["medv"].values
ols = sm.OLS(y, X).fit()
ols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.858
# Model:                            OLS   Adj. R-squared:                  0.858
# Method:                 Least Squares   F-statistic:                     3015.
# Date:                Wed, 08 Oct 2014   Prob (F-statistic):          1.19e-213
# Time:                        18:41:55   Log-Likelihood:                -867.25
# No. Observations:                 500   AIC:                             1736.
# Df Residuals:                     499   BIC:                             1741.
# Df Model:                           1
# ...
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1             5.8530      0.107     54.911      0.000         5.644     6.062
# ...

# %%
print ols.rsquared
print ols.fvalue
print ols.pvalues
# Out:
# 0.858007566088
# 3015.27175557
# [  1.19110924e-213]

# %%
# now let's make a model with multiple regressors (3)
X = np.random.random(size=(samples, 4)) # The size of the input array is expected to be [n_samples, n_features]
#X = sm.add_constant(X) #Our model needs an intercept so we add a column of 1s
beta = [1, .1, .5, .4] 
e = np.random.random(samples)
y = np.dot(X, beta) + e 
model = LinearRegression(fit_intercept=True)
model.fit(X, y)
print ("Model coefficient(s): %s, and intercept: %s"
       % (model.coef_, model.intercept_))
plt.plot(X,y,'o')
# Out:
# Model coefficient(s): [ 0.99995276  0.0548837   0.47361693  0.42653709], and intercept: 0.514819936946
# ...

# %%
# now with statsmodels
ols = sm.OLS(y, X).fit()
ols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.958
# Model:                            OLS   Adj. R-squared:                  0.958
# Method:                 Least Squares   F-statistic:                     2852.
# Date:                Wed, 08 Oct 2014   Prob (F-statistic):               0.00
# Time:                        19:19:32   Log-Likelihood:                -142.58
# No. Observations:                 500   AIC:                             293.2
# Df Residuals:                     496   BIC:                             310.0
# Df Model:                           4
# ...
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1             1.2136      0.043     28.295      0.000         1.129     1.298
# ...

# %%
import seaborn as sns
#fig, ax = plt.subplots(figsize=(8,6))

#ax.plot(X, y, 'o', label="data")
#ax.plot(X, y_hat, 'b-', label="predicted")
#fig = sm.graphics.plot_partregress("prestige", "income", ["education"], data=prestige, ax=ax)
sm.graphics.plot_partregress_grid(ols)
