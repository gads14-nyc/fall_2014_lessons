# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm

# %%
np.random.seed(0)
samples = 500
X = np.random.random(size=(samples, 1)) # The size of the input array is expected to be [n_samples, n_features]
y = 2 + 3 * X.squeeze() + np.random.normal(size=samples)
model = LinearRegression(fit_intercept=True)
model.fit(X, y)
print ("Model coefficient: %.5f, and intercept: %.5f" % (model.coef_, model.intercept_))
X_test = np.linspace(0, 1, 100).reshape(100,1)
y_hat = model.predict(X_test)
plt.plot(X,y,'o')
plt.plot(X_test, y_hat, 'o')
# Out:
# Model coefficient: 3.02895, and intercept: 1.88551

# %%
# now let's try the same procedure with statsmodels
ols = sm.OLS(y, X).fit()
ols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.858
# Model:                            OLS   Adj. R-squared:                  0.858
# Method:                 Least Squares   F-statistic:                     3015.
# Date:                Wed, 08 Oct 2014   Prob (F-statistic):          1.19e-213
# Time:                        19:11:32   Log-Likelihood:                -867.25
# No. Observations:                 500   AIC:                             1736.
# Df Residuals:                     499   BIC:                             1741.
# Df Model:                           1
# ...
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1             5.8530      0.107     54.911      0.000         5.644     6.062
# ...

# %%
# how does it work for multiple linear regression?
# let's use real data for this
df = pd.read_csv('./datasets/africa_ph.csv')

# %%
df.head()
# Out:
#    Unnamed: 0      PIDN        pH      ELEV      REF2      BSAN      LSTN  \
# 0          32  d9u06tdU -0.044436  0.904900 -0.352505 -0.710145 -0.371001
# 1          33  qsQFu3ef -0.455961  0.904900 -0.352505 -0.710145 -0.371001
# 2          34  C4kj5IMN -0.549490  0.971715 -0.352505 -0.702899 -0.399312
# 3          35  p1SCgsM8 -0.951662  0.971715 -0.352505 -0.702899 -0.399312
# 4          36  UqyLWYTl -0.427903  0.929399 -0.506494 -0.695652 -0.543779
#
#    Infrared01  Infrared02  Infrared03  Infrared04  Infrared05
# 0    0.378298    0.056228    1.349732     1.81377     1.65483
# 1    0.374321    0.072229    1.459569     1.78552     1.62982
# 2    0.390773    0.048228    1.555917     1.73194     1.63317
# 3    0.385719    0.047679    1.662981     1.68115     1.69190
# 4    0.411471    0.043002    1.522019     1.71672     1.68936

# %%
df.columns
# Out:
# Index([u'Unnamed: 0', u'PIDN', u'pH', u'ELEV', u'REF2', u'BSAN', u'LSTN', u'Infrared01', u'Infrared02', u'Infrared03', u'Infrared04', u'Infrared05'], dtype='object')

# %%
predictors = ['ELEV', 'REF2', 'BSAN', 'LSTN', 'Infrared01', 'Infrared02', 'Infrared03', 'Infrared04', 'Infrared05']
ols = sm.OLS(df['pH'], df[predictors]).fit()
ols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                     pH   R-squared:                       0.503
# Model:                            OLS   Adj. R-squared:                  0.497
# Method:                 Least Squares   F-statistic:                     81.69
# Date:                Wed, 08 Oct 2014   Prob (F-statistic):          3.60e-104
# Time:                        19:16:49   Log-Likelihood:                -760.25
# No. Observations:                 736   AIC:                             1539.
# Df Residuals:                     727   BIC:                             1580.
# Df Model:                           9
# ...
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# ELEV          -0.0508      0.040     -1.269      0.205        -0.129     0.028
# ...

# %%
df[predictors].corr()
# Out:
#                 ELEV      REF2      BSAN      LSTN  Infrared01  Infrared02  \
# ELEV        1.000000 -0.496091 -0.463918 -0.880093    0.480666    0.232696
# REF2       -0.496091  1.000000  0.489005  0.543130   -0.254778   -0.231947
# BSAN       -0.463918  0.489005  1.000000  0.377920   -0.357432    0.265897
# LSTN       -0.880093  0.543130  0.377920  1.000000   -0.413861   -0.182222
# Infrared01  0.480666 -0.254778 -0.357432 -0.413861    1.000000    0.102746
# Infrared02  0.232696 -0.231947  0.265897 -0.182222    0.102746    1.000000
# Infrared03 -0.062068  0.181667  0.162113  0.128976    0.020156    0.397333
# Infrared04 -0.410551  0.168279  0.151414  0.262317   -0.349524   -0.297950
# Infrared05  0.458919 -0.269370 -0.292186 -0.335978    0.493270    0.437130
#
#             Infrared03  Infrared04  Infrared05
# ELEV         -0.062068   -0.410551    0.458919
# REF2          0.181667    0.168279   -0.269370
# BSAN          0.162113    0.151414   -0.292186
# ...
