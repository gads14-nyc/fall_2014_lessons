# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("./lab04/nyt1.csv")
df = df[df.Signed_In==1]
df = df[df.Impressions>0]

# %%
df[df.Impressions==0].count()
# Out:
# Age            0
# Gender         0
# Impressions    0
# Clicks         0
# Signed_In      0
# dtype: int64

# %%
df.describe()
# Out:
#                  Age         Gender    Impressions         Clicks  Signed_In
# count  319198.000000  319198.000000  319198.000000  319198.000000     319198
# mean       42.062547       0.523644       5.044129       0.071958          1
# std        16.307554       0.499441       2.208280       0.269493          0
# min         7.000000       0.000000       1.000000       0.000000          1
# 25%        29.000000       0.000000       3.000000       0.000000          1
# 50%        41.000000       1.000000       5.000000       0.000000          1
# 75%        53.000000       1.000000       6.000000       0.000000          1
# max       108.000000       1.000000      20.000000       3.000000          1

# %%
# Create a new variable "age_group" that puts users into categories: ["<18", "18-24", "25-34", "35-44", "45-54", "55-64", "65+"]

# %%
def age_grouping(age):
    if age < 18:
        return "<18"
    elif age >= 18 and age < 25:
        return "18-24"
    elif age >=25 and age < 35:
        return "25-34"
    elif age >=35 and age < 45:
        return "35-44"
    elif age >=45 and age < 55:
        return "45-54"
    elif age >=55 and age < 65:
        return "55-64"
    elif age > 65:
        return "65+"
    else:
        return np.nan

# %%
df['age_group'] = df.Age.apply(lambda x: age_grouping(x))
df[['Age', 'age_group']].head(30)
# Out:
#     Age age_group
# 0    36     35-44
# 1    73       65+
# 2    30     25-34
# 3    49     45-54
# 4    47     45-54
# 5    47     45-54
# 7    46     45-54
# 8    16       <18
# 9    52     45-54
# 11   21     18-24
# 13   57     55-64
# 14   31     25-34
# 16   40     35-44
# 17   31     25-34
# 18   38     35-44
# 20   59     55-64
# 21   61     55-64
# 22   48     45-54
# 23   29     25-34
# 25   19     18-24
# 26   19     18-24
# 27   48     45-54
# 28   48     45-54
# 29   21     18-24
# 30   23     18-24
# 31   66       65+
# 32   23     18-24
# 33   44     35-44
# 34   32     25-34
# 35   22     18-24

# %%
# Plot distributions of number of impressions and CTR for each age group

# %%
df['ctr'] = df.Clicks / df.Impressions

# %%
for index, group in df[df.ctr>0].groupby('age_group'):
    #print group.ctr.head()
    n, bins, patches = plt.hist(group.ctr.values, bins=20, normed=1, alpha=0.75)
    plt.xlabel('CTR')
    plt.ylabel('Probability')
    plt.title('Histogram of group: %s' % index)
    plt.show()

# %%
df[df.ctr>0].groupby('age_group').count()
# Out:
#             Age  Gender  Impressions  Clicks  Signed_In   ctr
# age_group
# 18-24      2107    2107         2107    2107       2107  2107
# 25-34      2870    2870         2870    2870       2870  2870
# 35-44      3592    3592         3592    3592       3592  3592
# 45-54      3139    3139         3139    3139       3139  3139
# 55-64      4337    4337         4337    4337       4337  4337
# 65+        3950    3950         3950    3950       3950  3950
# <18        1933    1933         1933    1933       1933  1933

# %%
f, axes = plt.subplots(7, 1, sharex=True, figsize=(20, 26))

plt.xlabel('CTR')
for i, (index, group) in enumerate(df[df.ctr>0].groupby('age_group')):
    sns.kdeplot(group.ctr.values, alpha=0.5, shade=True, label=index, ax=axes[i])

# %%
for index, group in df[df.ctr>0].groupby('age_group'):
    #print group.ctr.head()
    plt.boxplot(group.ctr.values)
    plt.xlabel('CTR')
    plt.ylabel('Probability')
    plt.title('Boxplot of group: %s' % index)
    plt.show()

# %%
sns.boxplot(df[df.ctr>0].ctr.values, groupby='age_group')

# %%
df[df.ctr>0].boxplot(column='ctr',by='age_group')

# %%
df[df.ctr>0].groupby('age_group')['ctr'].hist(bins=30)
# Out:
# age_group
# 18-24        Axes(0.125,0.125;0.775x0.775)
# 25-34        Axes(0.125,0.125;0.775x0.775)
# 35-44        Axes(0.125,0.125;0.775x0.775)
# 45-54        Axes(0.125,0.125;0.775x0.775)
# 55-64        Axes(0.125,0.125;0.775x0.775)
# 65+          Axes(0.125,0.125;0.775x0.775)
# <18          Axes(0.125,0.125;0.775x0.775)
# Name: ctr, dtype: object

# %%
df[df.ctr>0].groupby('age_group')['ctr'].hist(bins=50, sharey=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-106-6457049520ce> in <module>()
# ----> 1 df[df.ctr>0].groupby('age_group')['ctr'].hist(bins=50, sharey=True)
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/groupby.pyc in wrapper(*args, **kwargs)
#     530             # exception below
#     531             if name in _plotting_methods:
# --> 532                 return self.apply(curried)
#     533
#     534             try:
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/groupby.pyc in apply(self, func, *args, **kwargs)
#     635             return func(g, *args, **kwargs)
#     636
# --> 637         return self._python_apply_general(f)
#     638
#     639     def _python_apply_general(self, f):
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/groupby.pyc in _python_apply_general(self, f)
#     639     def _python_apply_general(self, f):
# ...
