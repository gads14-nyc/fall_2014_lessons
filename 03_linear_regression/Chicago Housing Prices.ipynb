# %%
import pandas
import sklearn

# %%
house_data = pandas.read_csv("../gads-materials/chicagohouseprices2.csv")

# %%
house_data.describe()
# Out:
#                 Price       Bath  CrimeIndex  MinutesToLoop  MilesToLake  \
# count      219.000000  70.000000  219.000000     219.000000   219.000000
# mean    483431.050228   2.271429    4.663607       9.698630     3.420411
# std     400124.919077   0.883364    1.418146       2.898995     0.352522
# min      24500.000000   1.000000    1.090000       6.000000     2.770000
# 25%     319000.000000   2.000000    3.940000       8.000000     3.150000
# 50%     390000.000000   2.000000    4.930000       9.000000     3.400000
# 75%     512500.000000   3.000000    5.580000      10.000000     3.685000
# max    3686000.000000   4.000000    8.080000      22.000000     4.200000
#
#               Age  LotSizeSqft  HouseSizeSqft  SchoolIndex
# count  219.000000   219.000000     219.000000   219.000000
# mean    29.424658   873.200913     699.977169    49.197717
# std     49.155880  1392.893683    1175.278922    18.554525
# min      0.000000     0.000000       0.000000    16.700000
# ...

# %%
house_data.corr()
# Out:
#                    Price      Bath  CrimeIndex  MinutesToLoop  MilesToLake  \
# Price           1.000000  0.113943    0.118667      -0.034644    -0.072433
# Bath            0.113943  1.000000    0.163785       0.166330    -0.157517
# CrimeIndex      0.118667  0.163785    1.000000       0.194745     0.102382
# MinutesToLoop  -0.034644  0.166330    0.194745       1.000000     0.374829
# MilesToLake    -0.072433 -0.157517    0.102382       0.374829     1.000000
# Age             0.237720 -0.039220   -0.036644      -0.023820    -0.047087
# LotSizeSqft     0.443341 -0.029979   -0.008807      -0.053292     0.006240
# HouseSizeSqft   0.456272  0.698526    0.070952      -0.032437    -0.046517
# SchoolIndex    -0.072403 -0.047992   -0.100256      -0.196728    -0.205966
# EstimatedPrice  0.983784  0.105632    0.122793      -0.034185    -0.082604
#
#                      Age  LotSizeSqft  HouseSizeSqft  SchoolIndex  \
# Price           0.237720     0.443341       0.456272    -0.072403
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = linreg.fit(house_data[['EstimatedPrice']], house_data['Price'])

# %%
b1 = reg.coef_
print b1
# Out:
# [ 0.98938934]

# %%
cov = house_data.cov()['Price']['EstimatedPrice']
print cov
# Out:
# 156611562184.0

# %%
estprice_var = house_data.var()['EstimatedPrice']
print estprice_var
# Out:
# 158291136126.0

# %%
print cov/estprice_var
# Out:
# 0.989389336745
