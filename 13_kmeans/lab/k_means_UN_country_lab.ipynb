# %%
# %pylab inline
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/TeachingDataScience/data-science-course/forstudentviewing/15_kmeans/un.csv")
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
focus = ['lifeMale', 'lifeFemale','infantMortality','GDPperCapita']

# %%
df_focus = df[focus]

# %%
##TODO: Number of missing vars for each column?

# %%
pd.scatter_matrix(df_focus, figsize=(10,10))
# Out:
# array([[<matplotlib.axes.AxesSubplot object at 0x4fc7d50>,
#         <matplotlib.axes.AxesSubplot object at 0x509e810>,
#         <matplotlib.axes.AxesSubplot object at 0x50bdcd0>,
#         <matplotlib.axes.AxesSubplot object at 0x51f8390>],
#        [<matplotlib.axes.AxesSubplot object at 0x520ce90>,
#         <matplotlib.axes.AxesSubplot object at 0x537e2d0>,
#         <matplotlib.axes.AxesSubplot object at 0x539e6d0>,
#         <matplotlib.axes.AxesSubplot object at 0x54fa890>],
#        [<matplotlib.axes.AxesSubplot object at 0x551ac90>,
#         <matplotlib.axes.AxesSubplot object at 0x569a0d0>,
#         <matplotlib.axes.AxesSubplot object at 0x56b01d0>,
#         <matplotlib.axes.AxesSubplot object at 0x58325d0>],
#        [<matplotlib.axes.AxesSubplot object at 0x58519d0>,
#         <matplotlib.axes.AxesSubplot object at 0x59aead0>,
#         <matplotlib.axes.AxesSubplot object at 0x59cded0>,
#         <matplotlib.axes.AxesSubplot object at 0x5b3f310>]], dtype=object)

# %%
df_focus = df_focus.dropna(axis=0)

# %%
from sklearn.cluster import KMeans
km = KMeans(3,init='k-means++')

# %%
c=km.predict(df_focus)

# %%
plt.plot(df_focus['GDPperCapita'][c==0], df_focus['lifeFemale'][c==0],'ro', label ='Undeveloped')
plt.plot(df_focus['GDPperCapita'][c==1], df_focus['lifeFemale'][c==1],'bo', label ='Developing')
plt.plot(df_focus['GDPperCapita'][c==2], df_focus['lifeFemale'][c==2],'go', label ='Developed')
plt.xlabel('GDP')
plt.ylabel('Female Life Expectancy')
legend(numpoints=1)

# %%
X = df_focus[['GDPperCapita']]
Y = df_focus[['infantMortality']]
