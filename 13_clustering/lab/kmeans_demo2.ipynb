#  [ -1.73073370e+00  -3.65174553e+00]
#  [ -1.03807232e+00  -4.27576244e+00]
#  [ -1.59744161e+00  -9.22727724e+00]
#  [ -2.30204923e+00  -3.51919064e+00]
#  [ -2.33387670e+00  -2.97014763e+00]
#  [ -6.53474093e+00   2.85450116e+00]
#  [ -5.14114716e+00   1.39249644e+00]
#  [ -1.15181673e+00  -9.97586489e+00]
#  [ -5.78630750e+00   2.63413215e+00]
#  [  8.41206338e-01  -9.04713602e-04]
#  [ -1.29188605e+00  -3.39147383e+00]
#  [ -1.94193893e+00  -3.85774954e+00]
#  [ -2.12304348e+00  -3.09747032e+00]
#  [  1.57401030e+00  -1.10051312e+00]
#  [ -1.28757192e+00  -3.18155513e+00]
#  [ -2.69119668e-02  -1.27042439e+00]
#  [ -1.68427225e+00  -2.88337622e+00]
#  [ -6.63370949e+00   2.21641044e+00]
#  [ -1.06335379e+00  -8.84228575e+00]
#  [ -5.39051279e+00   2.22091811e+00]
#  [ -1.75516877e+00  -3.67342083e+00]
#  [  4.72287423e-02  -2.90787292e+00]
#  [ -6.20390511e+00   2.96016961e+00]
#  [  7.83591316e-01  -1.35971660e+00]
#  [ -5.23924424e+00   2.53673400e+00]
#  [ -1.80907807e+00  -9.93597917e+00]
#  [ -1.46793667e+00  -9.51871074e+00]
#  [ -3.36475171e-01  -1.33927846e+00]
#  [ -2.10335132e+00  -3.17710573e+00]
#  [  4.26682921e-01  -1.07700587e+00]
#  [  6.54411769e-01  -2.01327166e+00]
#  [ -1.75443399e+00  -3.18139123e+00]
#  [ -1.24454497e+00  -3.04459544e+00]
#  [  1.40560106e+00  -6.69445687e-01]
#  [ -2.21414728e+00  -8.61588303e+00]
#  [ -3.85268101e+00   2.79597977e+00]
#  [ -5.72746065e+00   2.69652953e+00]
#  [ -7.79919014e-01  -9.67202162e+00]
#  [ -6.13414125e+00   2.64260469e+00]
#  [ -1.71915590e+00  -9.55969245e+00]]
# [3 3 2 1 3 3 0 3 1 3 1 3 0 2 1 0 3 2 0 0 2 1 1 0 0 1 1 1 1 3 3 0 1 0 1 3 1
#  3 0 1 0 0 0 0 3 2 0 1 2 3 2 1 0 3 0 1 2 2 2 2 2 2 0 2 2 3 3 0 3 1 2 2 2 1
#  2 1 2 3 0 3 2 2 3 1 3 0 0 1 2 1 1 2 2 1 0 3 3 0 3 0]

# %% [markdown]
# ### As usual, we first *plot* the data to get a feeling of what we're dealing with:

# %%
plt.scatter(X[:,0], X[:,1]);

# %% [markdown]
# ### The data looks like it may contain four different "clusters".
#
# In fact, this is how it was created above.
#
# We can plot this information as well, using color:

# %%
plt.scatter(X[:,0], X[:,1], c=Y);

# %% [markdown]
# Normally, you do not know the information in `Y`, however.
#
# You could try to recover it from the data alone.
#
# This is what the kMeans algorithm does.

# %% [markdown]
# ### Check out the docs on sklearn's [Kmeans](http://scikit-learn.org/stable/modules/generated/sklearn.cluster.KMeans.html)

# %% [markdown]
# ##### class sklearn.cluster.KMeans(n_clusters=8, init='k-means++', n_init=10, max_iter=300, tol=0.0001, precompute_distances=True, verbose=0, random_state=None, copy_x=True, n_jobs=1)

# %%
from sklearn.cluster import KMeans
kmeans1 = KMeans(n_clusters=num_blobs, random_state=8, verbose=True)
Y_hat = kmeans1.fit(X).labels_
print Y_hat
# Out:
# Initialization complete
# Iteration  0, inertia 102.527
# Iteration  1, inertia 54.687
# Converged at iteration 1
# Initialization complete
# Iteration  0, inertia 81.746
# Iteration  1, inertia 54.944
# Iteration  2, inertia 54.687
# Converged at iteration 2
# Initialization complete
# Iteration  0, inertia 68.981
# Iteration  1, inertia 54.944
# Iteration  2, inertia 54.687
# Converged at iteration 2
# Initialization complete
# Iteration  0, inertia 100.132
# Iteration  1, inertia 54.944
# Iteration  2, inertia 54.687
# Converged at iteration 2
# Initialization complete
# Iteration  0, inertia 59.405
# Iteration  1, inertia 54.944
# Iteration  2, inertia 54.687
# Converged at iteration 2
# Initialization complete
# Iteration  0, inertia 72.943
# Iteration  1, inertia 54.944
# Iteration  2, inertia 54.687
# Converged at iteration 2
# Initialization complete
# Iteration  0, inertia 80.840
# Iteration  1, inertia 54.687
# Converged at iteration 1
# Initialization complete
# Iteration  0, inertia 79.498
# Iteration  1, inertia 54.687
# Converged at iteration 1
# Initialization complete
# Iteration  0, inertia 81.236
# Iteration  1, inertia 54.984
# Iteration  2, inertia 54.687
# Converged at iteration 2
# Initialization complete
# Iteration  0, inertia 86.385
# Iteration  1, inertia 54.944
# Iteration  2, inertia 54.687
# Converged at iteration 2
# [2 2 1 3 2 2 0 2 3 2 3 2 0 1 3 0 2 1 0 0 1 3 3 0 0 3 3 3 3 2 2 0 3 0 3 2 3
#  2 0 3 0 0 0 0 2 1 0 3 1 2 1 3 0 2 0 3 1 1 1 1 1 1 0 1 1 2 2 0 2 3 1 1 1 3
#  1 3 1 2 0 2 1 1 2 3 2 0 0 3 1 3 3 1 1 3 0 2 2 0 2 0]

# %% [markdown]
# ### Now the label assignments should be quite similar to `Y`, up to a different ordering of the colors:

# %%
plt.scatter(X[:,0], X[:,1], c=Y_hat);

# %% [markdown]
# ### Often, you're not so much interested in the assignments to the centroids (means).
#
# You'll want to have a closer look at the centroids themselves.
#
# The centroids can be seen as *representatives* of their respective cluster.

# %%
plt.scatter(X[:,0], X[:,1], c=Y_hat, alpha=0.4)
ctroids = kmeans1.cluster_centers_
plt.scatter(ctroids[:,0], ctroids[:,1], s=100, c=np.unique(Y_hat))
print ctroids
# Out:
# [[-1.40113893 -9.37815706]
#  [-1.52252875 -3.51768581]
#  [-5.77707127  2.47726437]
#  [ 0.92452987 -1.21956947]]

# %% [markdown]
# ## Let's try to find an ideal value of K using the elbow method

# %%
K = range(1,10)

inertias = []
for k in K:
    # create a new KMeans object for each value of k
    kmeans = KMeans(n_clusters=k, random_state=8)
    kmeans.fit(X)
    inertias.append(kmeans.inertia_) # inertia: Sum of distances of samples to their closest cluster center

# %%
ideal_k = num_blobs -1 # (we know in advance that this is the ideal value for k)

# plot elbow curve
fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111)
ax.plot(K, inertias, 'b*-')

# plot the red circle
ax.plot(K[ideal_k], inertias[ideal_k], marker='o', markersize=12, 
      markeredgewidth=2, markeredgecolor='r', markerfacecolor='None')
plt.grid(True)
plt.xlabel('Number of clusters')
plt.ylabel('Sum of distances of samples to their closest cluster center')
tt = plt.title('Elbow for K-Means clustering')
